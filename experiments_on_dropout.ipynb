# %%
from others.utensils import *
# Out:
# /Users/heyuhao/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
df = pd.read_csv('/Users/heyuhao/Documents/GitHub/school_project/cz4042/assignment1/assignment1_question_a/ctg_data_cleaned.csv')

# %%
df.head()
# Out:
#     LB     AC   FM     UC     DL   DS   DP  ASTV  MSTV  ALTV  ...  Max  Nmax  \
# 0  120  0.000  0.0  0.000  0.000  0.0  0.0    73   0.5    43  ...  126     2
# 1  132  0.006  0.0  0.006  0.003  0.0  0.0    17   2.1     0  ...  198     6
# 2  133  0.003  0.0  0.008  0.003  0.0  0.0    16   2.1     0  ...  198     5
# 3  134  0.003  0.0  0.008  0.003  0.0  0.0    16   2.4     0  ...  170    11
# 4  132  0.007  0.0  0.008  0.000  0.0  0.0    16   2.4     0  ...  170     9
#
#    Nzeros  Mode  Mean  Median  Variance  Tendency  CLASS  NSP
# 0       0   120   137     121        73         1      9    2
# 1       1   141   136     140        12         0      6    1
# 2       1   141   135     138        13         0      6    1
# 3       0   137   134     137        13         1      6    1
# 4       0   137   136     138        11         1      2    1
#
# [5 rows x 23 columns]

# %%
def scale(X, decimals):
    return np.round((X - np.mean(X, axis=0))/ np.std(X, axis=0), decimals=decimals)

seed = 10

np.random.seed(seed)

data = df.values
np.random.shuffle(data)

X = data[:, :-2]
y_temp = data[:, -1].astype(int)

X = scale(X, 4)

y = np.zeros((y_temp.shape[0], 3))
y[np.arange(y_temp.shape[0]), y_temp - 1] = 1

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

X_train, X_test, y_train, y_test = np.array(X_train), np.array(X_test), np.array(y_train), np.array(y_test)

# %%
#a)

lr = 1e-2
decay = 1e-6
batch_size = 32
epochs = 10000
epochs_interval =100
early_stop_threshold = 1e-2

model = Sequential([
    Dense(10, input_dim=X_train.shape[1], activation='relu', kernel_initializer='lecun_normal', kernel_regularizer=l2(decay)),
    Dense(10, activation='relu', kernel_initializer='he_normal', kernel_regularizer=l2(decay)),
    Dense(3, activation='softmax' ,kernel_initializer='he_normal', kernel_regularizer=l2(decay))
    ])

model.compile(optimizer=optimizers.SGD(lr=lr),
                loss='categorical_crossentropy',
                metrics=['accuracy'])

h = model.fit(X_train, y_train, batch_size=batch_size, epochs=epochs, verbose=1, validation_data=(X_test, y_test), shuffle=True)

# h

        

plt.figure()
plt.plot(h.history['acc'])
plt.plot(h.history['val_acc'])
plt.title('accurazy')
plt.xlabel('epoch')
plt.legend(['train_acc', 'val_acc',], loc='upper left')
# Out:
# Train on 1488 samples, validate on 638 samples
# Epoch 1/10000
# 1488/1488 [==============================] - 0s 184us/step - loss: 0.7881 - acc: 0.7117 - val_loss: 0.6880 - val_acc: 0.7727
# Epoch 2/10000
# 1488/1488 [==============================] - 0s 48us/step - loss: 0.6233 - acc: 0.7769 - val_loss: 0.5857 - val_acc: 0.8025
# Epoch 3/10000
# 1488/1488 [==============================] - 0s 36us/step - loss: 0.5478 - acc: 0.8091 - val_loss: 0.5249 - val_acc: 0.8229
# Epoch 4/10000
# 1488/1488 [==============================] - 0s 33us/step - loss: 0.5008 - acc: 0.8159 - val_loss: 0.4849 - val_acc: 0.8260
# Epoch 5/10000
# 1488/1488 [==============================] - 0s 30us/step - loss: 0.4678 - acc: 0.8226 - val_loss: 0.4560 - val_acc: 0.8276
# Epoch 6/10000
# 1488/1488 [==============================] - 0s 30us/step - loss: 0.4424 - acc: 0.8286 - val_loss: 0.4337 - val_acc: 0.8307
# Epoch 7/10000
# ...

# %%
#a)

lr = 1e-2
decay = 1e-3
batch_size = 32
epochs = 4000
epochs_interval =100
early_stop_threshold = 1e-2

model = Sequential([
    Dense(10, input_dim=X_train.shape[1], activation='relu', kernel_initializer='lecun_normal', kernel_regularizer=l2(decay)),
    Dropout(rate=0.2),
    Dense(10, activation='relu', kernel_initializer='he_normal', kernel_regularizer=l2(decay)),
    Dropout(rate=0.2),
    Dense(3, activation='softmax' ,kernel_initializer='he_normal', kernel_regularizer=l2(decay))
    ])

model.compile(optimizer=optimizers.SGD(lr=lr),
                loss='categorical_crossentropy',
                metrics=['accuracy'])

h = model.fit(X_train, y_train, batch_size=batch_size, epochs=epochs, verbose=1, validation_data=(X_test, y_test), shuffle=True)

# h

        

plt.figure()
plt.plot(h.history['acc'])
plt.plot(h.history['val_acc'])
plt.title('accurazy')
plt.xlabel('epoch')
plt.legend(['train_acc', 'val_acc',], loc='upper left')
# Out:
# WARNING:tensorflow:From /Users/heyuhao/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# Train on 1488 samples, validate on 638 samples
# Epoch 1/4000
# 1488/1488 [==============================] - 0s 303us/step - loss: 0.9267 - acc: 0.7043 - val_loss: 0.8016 - val_acc: 0.7743
# Epoch 2/4000
# 1488/1488 [==============================] - 0s 47us/step - loss: 0.8036 - acc: 0.7507 - val_loss: 0.7260 - val_acc: 0.7853
# Epoch 3/4000
# 1488/1488 [==============================] - 0s 54us/step - loss: 0.7427 - acc: 0.7749 - val_loss: 0.6724 - val_acc: 0.7931
# Epoch 4/4000
# 1488/1488 [==============================] - 0s 53us/step - loss: 0.7097 - acc: 0.7688 - val_loss: 0.6352 - val_acc: 0.7947
# Epoch 5/4000
# ...
